# %%
from youtube_transcript_api import YouTubeTranscriptApi
YouTubeTranscriptApi.get_transcript('Ao41FrJFgvQ')
# Out:
# [{'text': 'OK.', 'start': 15.966, 'duration': 1.568},
#  {'text': "Let's get started.", 'start': 17.534, 'duration': 2.736},
#  {'text': "How's everyone doing?", 'start': 20.27, 'duration': 1.535},
#  {'text': 'Wonderful.', 'start': 21.805, 'duration': 0.867},
#  {'text': "Come on, let's do\nbetter than that.",
#   'start': 22.672,
#   'duration': 1.935},
#  {'text': 'How is everyone doing?', 'start': 24.607, 'duration': 1.702},
#  {'text': 'Wonderful!', 'start': 26.309, 'duration': 0.768},
#  {'text': 'Thank you.', 'start': 27.077, 'duration': 1.268},
#  {'text': 'Welcome to 3.091.', 'start': 28.345, 'duration': 3.136},
#  {'text': 'This is the first day.', 'start': 31.481, 'duration': 2.236},
#  {'text': "And I'm really excited.", 'start': 33.717, 'duration': 1.668},
#  {'text': 'I hope you are too.', 'start': 35.385, 'duration': 1.868},
#  {'text': "In this very first\nlecture, we're",
#   'start': 37.253,
#   'duration': 2.203},
# ...
