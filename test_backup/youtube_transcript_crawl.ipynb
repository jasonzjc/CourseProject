# %%
from youtube_transcript_api import YouTubeTranscriptApi
x = YouTubeTranscriptApi.get_transcript('YrHlHbtiSM0')

# %%
x[1]['text'].replace("\n"," ")
# Out:
# "And I'm very happy if you know the linear algebra"

# %%
x[0]['text'] = x[0]['text'].replace("\n"," ")

# %%
x
# Out:
# [{'text': "GILBERT STRANG: Well, I'm Gil Strang.",
#   'start': 13.5,
#   'duration': 2.22},
#  {'text': "And I'm very happy if you know the linear algebra",
#   'start': 15.72,
#   'duration': 4.93},
#  {'text': 'videos on OpenCourseWare\nor on YouTube.',
#   'start': 20.65,
#   'duration': 3.97},
#  {'text': "That's for the\nmath course 18.06.",
#   'start': 24.62,
#   'duration': 4.13},
#  {'text': "And I'm even happier\nif you like them.",
#   'start': 28.75,
#   'duration': 3.659},
#  {'text': "And I'm here today to update\nthem for several reasons.",
#   'start': 32.409,
#   'duration': 6.181},
#  {'text': 'Well, a lots happened in\nlinear algebra in these years.',
#   'start': 38.59,
#   'duration': 6.73},
#  {'text': 'Fortunately, the\nwhole subject has just',
#   'start': 45.32,
#   'duration': 2.96},
#  {'text': 'become more and more essential,\nmore and more important, more',
#   'start': 48.28,
#   'duration': 3.48},
# ...
